# %% [markdown]
# # Model evaluation

# %% [markdown]
# ## Predicted vs Empirical pRF estimates

# %%
import sys
sys.path.append('../')
from functions.evaluation import predicted_vs_empirical

dataset_name = 'hcp'
path = '../HCP/freesurfer/'
retinotopic_maps = ['polarAngle', 'eccentricity', 'pRFsize']

for hemispheres in ['both', 'lh', 'rh']:
    for threshold in [None, 10, 35]:
        predicted_vs_empirical(path, dataset_name, retinotopic_maps, hemispheres = hemispheres, threshold=threshold)
# Out:
# Threshold: 10
# Threshold: 10
# Threshold: 10
# Threshold: 35
# Threshold: 35
# Threshold: 35
# Threshold: 10
# Threshold: 10
# Threshold: 10
# Threshold: 35
# Threshold: 35
# Threshold: 35
# Threshold: 10
# Threshold: 10
# Threshold: 10
# Threshold: 35
# Threshold: 35
# Threshold: 35
